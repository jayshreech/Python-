# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_excel('C:\Users\Dell\AppData\Local\Temp\Rar$DIa9596.21897\AB_NYC_2019.xlsx')

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
plt.hist(df.price,bins=20,rwidth=0.8)
plt.xlabel('price')
plt.ylabel('count')
plt.show()

# %%
min_thresold,max_thresold=df.price.quantile([0.01,0.999])
min_thresold,max_thresold
# Out:
# (30.0, 3000.0)

# %%
df[df.price<min_thresold]
# Out:
#              id                                               name    host_id  \
# 957      375249                    Enjoy Staten Island Hospitality    1887999
# 2675    1428154                Central, Peaceful Semi-Private Room    5912572
# 2860    1620248      Large furnished 2 bedrooms- - 30 days Minimum    2196224
# 3020    1767037                 Small Cozy Room Wifi & AC near JFK    9284163
# 3918    2431607                      Bright, Airy Room Share for 2    4973668
# 3950    2459916                  $455 Cozy 1bd, BKLYN Sublet March   12577771
# 4647    3258197       Large 1br Duplex in Heart of Upper East Side   16477306
# 4751    3359315                    Sublet near Columbia University   16948705
# 5542    4031809                      Prewar classic NYC apartment.   20902552
# 5627    4093591                                    1 Room & 1 Bath   11090576
# 6108    4472904    Dorm Sz Room. Near 2 & 5 train 180 st Bronx zoo    1532337
# ...

# %%
df[df.price>max_thresold]
# Out:
#              id                                               name    host_id  \
# 1862     826690                   Sunny, Family-Friendly 2 Bedroom    4289240
# 2698    1448703                Beautiful 1 Bedroom in Nolita/Soho      213266
# 3537    2110145                 UWS 1BR w/backyard + block from CP    2151325
# 3695    2224896                NYC SuperBowl Wk 5 Bdrs River View    11353904
# 3720    2243699                SuperBowl Penthouse Loft 3,000 sqft    1483320
# 3774    2271504                   SUPER BOWL Brooklyn Duplex Apt!!   11598359
# 3788    2281142                 Prime NYC Location for Super Bowl     1427243
# 4345    2919330                   NearWilliamsburg bridge 11211 BK   14908606
# 4376    2952861                               Photography Location    1177497
# 4377    2953058                                      Film Location    1177497
# 6530    4737930                                 Spanish Harlem Apt    1235070
# ...

# %%
df1= df[(df.price<max_thresold) & (df.price>min_thresold)]
df1.shape
# Out:
# (48183, 16)

# %%
df1
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 9          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 10         5295                   Beautiful 1br on Upper West Side       7702
# ...

# %%
df1.price.describe()
# Out:
# count    48183.000000
# mean       148.772036
# std        153.594795
# min         31.000000
# 25%         70.000000
# 50%        110.000000
# 75%        179.000000
# max       2999.000000
# Name: price, dtype: float64

# %%
df1.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.818300e+04  4.818300e+04  48183.000000  48183.000000  48183.000000
# mean   1.896272e+07  6.723035e+07     40.729155    -73.952498    148.772036
# std    1.099404e+07  7.851540e+07      0.054231      0.045894    153.594795
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420     31.000000
# 25%    9.411247e+06  7.719674e+06     40.690355    -73.983190     70.000000
# 50%    1.960306e+07  3.038419e+07     40.723280    -73.955930    110.000000
# 75%    2.910493e+07  1.072455e+08     40.763180    -73.936960    179.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990   2999.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48183.000000       48183.000000       38312.000000
# mean         7.011104          23.393915           1.373749
# std         20.526646          44.701116           1.680887
# ...

# %%
plt.hist(df1.price,bins=20,rwidth=0.8)
plt.xlabel('price')
plt.ylabel('count')
plt.show()

# %%
df2=pd.read_excel(r'C:\Users\Dell\Documents\bhp.xlsx')

# %%
df2.head(10)
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0     2   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0     5  120.00    4
# 2               Uttarahalli      3 BHK      1440.0     2   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0     3   95.00    3
# 4                  Kothanur      2 BHK      1200.0     2   51.00    2
# 5                Whitefield      2 BHK      1170.0     2   38.00    2
# 6          Old Airport Road      4 BHK      2732.0     4  204.00    4
# 7              Rajaji Nagar      4 BHK      3300.0     4  600.00    4
# 8              Marathahalli      3 BHK      1310.0     3   63.25    3
# 9                     other  6 Bedroom      1020.0     6  370.00    6
#
#    price_per_sqft
# 0            3699
# 1            4615
# 2            4305
# 3            6245
# 4            4250
# 5            3247
# 6            7467
# 7           18181
# 8            4828
# ...

# %%
df2.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13200.000000  13200.000000  13200.000000  13200.000000    1.320000e+04
# mean    1555.302783      2.691136    112.276178      2.800833    7.920337e+03
# std     1237.323445      1.338915    149.175995      1.292843    1.067272e+05
# min        1.000000      1.000000      8.000000      1.000000    2.670000e+02
# 25%     1100.000000      2.000000     50.000000      2.000000    4.267000e+03
# 50%     1275.000000      2.000000     71.850000      3.000000    5.438000e+03
# 75%     1672.000000      3.000000    120.000000      3.000000    7.317000e+03
# max    52272.000000     40.000000   3600.000000     43.000000    1.200000e+07

# %%
df2.shape
# Out:
# (13200, 7)

# %% [markdown]
# df2.shape

# %%
min_thresold,max_thresold=df2.price_per_sqft.quantile([0.001,0.999])
min_thresold,max_thresold
# Out:
# (1366.184, 50959.36200000099)

# %%
df2[df2.price_per_sqft<min_thresold]
# Out:
#         location       size  total_sqft  bath  price  bhk  price_per_sqft
# 665    Yelahanka      3 BHK     35000.0     3  130.0    3             371
# 798        other  4 Bedroom     10961.0     4   80.0    4             729
# 1867       other  3 Bedroom     52272.0     2  140.0    3             267
# 2392       other  4 Bedroom      2000.0     3   25.0    4            1250
# 3934       other      1 BHK      1500.0     1   19.5    1            1300
# 5343       other      9 BHK     42000.0     8  175.0    9             416
# 5417      Ulsoor      4 BHK     36000.0     4  450.0    4            1250
# 5597    JP Nagar      2 BHK      1100.0     1   15.0    2            1363
# 7166   Yelahanka  1 Bedroom     26136.0     1  150.0    1             573
# 7862    JP Nagar      3 BHK     20000.0     3  175.0    3             875
# 8300     Kengeri      1 BHK      1200.0     1   14.0    1            1166
# 9144       other  4 Bedroom     10961.0     4   80.0    4             729
# ...

# %%
df2[df2.price_per_sqft>max_thresold]
# Out:
#                 location       size  total_sqft  bath   price  bhk  \
# 345                other  3 Bedroom        11.0     3    74.0    3
# 1005               other      1 BHK        15.0     1    30.0    1
# 1106               other  5 Bedroom        24.0     2   150.0    5
# 4044      Sarjapur  Road  4 Bedroom         1.0     4   120.0    4
# 4924               other      7 BHK         5.0     7   115.0    7
# 5911         Mysore Road  1 Bedroom        45.0     1    23.0    1
# 6356        Bommenahalli  4 Bedroom      2940.0     3  2250.0    4
# 7012               other      1 BHK       650.0     1   500.0    1
# 7575               other      1 BHK       425.0     1   750.0    1
# 7799               other      4 BHK      2000.0     3  1063.0    4
# 8307   Bannerghatta Road      5 BHK      2500.0     4  1400.0    5
# 9436        Indira Nagar  4 Bedroom      2400.0     5  1250.0    4
# 11447         Whitefield  4 Bedroom        60.0     4   218.0    4
# ...

# %%
df3=df2[(df2.price_per_sqft<max_thresold) & (df2.price_per_sqft>min_thresold)]
df3.shape
# Out:
# (13172, 7)

# %%
df3.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13172.000000  13172.000000  13172.000000  13172.000000    13172.000000
# mean    1537.861049      2.690100    111.591865      2.799651     6663.653735
# std      967.123711      1.337026    145.372047      1.291130     4141.020700
# min      250.000000      1.000000      8.000000      1.000000     1379.000000
# 25%     1100.000000      2.000000     50.000000      2.000000     4271.000000
# 50%     1274.500000      2.000000     71.550000      3.000000     5438.000000
# 75%     1670.000000      3.000000    120.000000      3.000000     7311.000000
# max    30400.000000     40.000000   3600.000000     43.000000    50349.000000

# %%
df3.price_per_sqft.mean()
# Out:
# 6663.6537351958705

# %%
df3.price_per_sqft.std()
# Out:
# 4141.020700174613

# %%
max_limit=df3.price_per_sqft.mean() + 4*df3.price_per_sqft.std()
max_limit
# Out:
# 23227.73653589432

# %%
min_limit=df3.price_per_sqft.mean() - 4*df3.price_per_sqft.std()
min_limit
# Out:
# -9900.429065502582

# %%
df4=df3[(df3.price_per_sqft< max_limit) & (df3.price_per_sqft>min_limit)]
df4.shape
# Out:
# (13047, 7)

# %%
plt.hist(df4.price_per_sqft,bins=20,rwidth=0.8)
plt.xlabel('price_per_sqft')
plt.ylabel('count')
plt.show()

# %%
from scipy.stats import norm
plt.hist(df3.price_per_sqft,bins=20,rwidth=0.8,density=True)
plt.xlabel('Height (inches)')
plt.ylabel('count')
rng=np.arange(-5000,df4.price_per_sqft.max(),100)
plt.plot(rng,norm.pdf(rng,df3.price_per_sqft.mean(),df3.price_per_sqft.std()))

# %%
df3['z-score']=(df3.price_per_sqft-df3.price_per_sqft.mean())/df3.price_per_sqft.std()
df3.head(10)
# Out:
# c:\users\dell\onedrive\documents\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0     2   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0     5  120.00    4
# 2               Uttarahalli      3 BHK      1440.0     2   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0     3   95.00    3
# 4                  Kothanur      2 BHK      1200.0     2   51.00    2
# 5                Whitefield      2 BHK      1170.0     2   38.00    2
# 6          Old Airport Road      4 BHK      2732.0     4  204.00    4
# ...

# %%
df5=pd.read_excel(r'C:\Users\Dell\Documents\height_weight.xlsx')

# %%
df5.head()
# Out:
#   gender     height      weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df5.describe()
# Out:
#              height        weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %%
plt.hist(df5.height,bins=40,rwidth=0.8)
plt.xlabel('height')
plt.ylabel('count')
plt.show()

# %%
plt.hist(df5.weight,bins=40,rwidth=0.8)
plt.xlabel('weight')
plt.ylabel('count')
plt.show()

# %%
Q1=df5.height.quantile(0.25)
Q3=df5.height.quantile(0.75)
Q1,Q3
# Out:
# (63.505620481218955, 69.1742617268347)

# %%
IQR=Q3-Q1
IQR
# Out:
# 5.668641245615746

# %%
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (55.00265861279534, 77.67722359525831)

# %%
df6 = df5[(df5.height>lower_limit)&(df5.height<upper_limit)]
df6
# Out:
#       gender     height      weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# 5       Male  67.253016  152.212156
# 6       Male  68.785081  183.927889
# 7       Male  68.348516  167.971110
# 8       Male  67.018950  175.929440
# 9       Male  63.456494  156.399676
# 10      Male  71.195382  186.604926
# 11      Male  71.640805  213.741169
# 12      Male  64.766329  167.127461
# 13      Male  69.283070  189.446181
# 14      Male  69.243732  186.434168
# 15      Male  67.645620  172.186930
# 16      Male  72.418317  196.028506
# 17      Male  63.974326  172.883470
# 18      Male  69.640060  185.983958
# 19      Male  67.936005  182.426648
# 20      Male  67.915050  174.115929
# 21      Male  69.439440  197.731422
# 22      Male  66.149132  149.173566
# 23      Male  75.205974  228.761781
# 24      Male  67.893196  162.006652
# ...

# %%
df7 = df5[(df5.weight>lower_limit)&(df5.weight<upper_limit)]
df7
# Out:
#       gender     height     weight
# 5360  Female  55.668202  68.982530
# 6624  Female  54.616858  71.393749
# 7935  Female  58.211650  77.523774
# 9285  Female  54.263133  64.700127
# 9566  Female  57.353093  72.750145

# %%
plt.hist(df6.height,bins=40,rwidth=0.8)
plt.xlabel('height')
plt.ylabel('count')
plt.show()

# %%
df5[(df5.height<lower_limit)|(df5.height>upper_limit)]
# Out:
#       gender     height      weight
# 994     Male  78.095867  255.690835
# 1317    Male  78.462053  227.342565
# 2014    Male  78.998742  269.989699
# 3285    Male  78.528210  253.889004
# 3757    Male  78.621374  245.733783
# 6624  Female  54.616858   71.393749
# 7294  Female  54.873728   78.606670
# 9285  Female  54.263133   64.700127

# %%
Q1=df5.weight.quantile(0.25)
Q3=df5.weight.quantile(0.75)
Q1,Q3
# Out:
# (135.8180513055015, 187.16952486868348)

# %%
IQR=Q3-Q1
IQR
# Out:
# 51.35147356318197

# %%
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (58.79084096072856, 264.19673521345646)
