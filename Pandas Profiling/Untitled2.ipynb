# %%
import os
import sys
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import pandas_profiling
from pandas_profiling import ProfileReport
# %matplotlib inline
# Out:
# c:\users\dell\onedrive\documents\lib\site-packages\pandas_profiling\plot.py:15: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "c:\users\dell\onedrive\documents\lib\runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "c:\users\dell\onedrive\documents\lib\runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "c:\users\dell\onedrive\documents\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\dell\onedrive\documents\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
# ...

# %%
df=pd.read_csv(r'C:\Users\Dell\Downloads\datasets_894_813759_2015.csv')

# %%
profile=pandas_profiling.ProfileReport(df)

# %%
profile
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.count()
# Out:
# Country                          158
# Region                           158
# Happiness Rank                   158
# Happiness Score                  158
# Standard Error                   158
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         158
# Freedom                          158
# Trust (Government Corruption)    158
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
df.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
sns.relplot(x='Country',y='Happiness Rank',data=df)

# %%
df=pd.read_csv(r'C:\Users\Dell\Downloads\datasets_723010_1257097_fatal-police-shootings-data.csv')

# %%
df.head(10)
# Out:
#    id                 name        date   manner_of_death       armed   age  \
# 0   3           Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4     Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5   John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8      Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9    Michael Rodriguez  2015-01-04              shot    nail gun  39.0
# 5  11    Kenneth Joe Brown  2015-01-04              shot         gun  18.0
# 6  13  Kenneth Arnold Buck  2015-01-05              shot         gun  22.0
# 7  15        Brock Nichols  2015-01-06              shot         gun  35.0
# 8  16        Autumn Steele  2015-01-06              shot     unarmed  34.0
# 9  17      Leslie Sapp III  2015-01-06              shot  toy weapon  47.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# ...

# %%
df.describe()
# Out:
#                 id          age
# count  5416.000000  5181.000000
# mean   3010.398264    37.117931
# std    1695.786456    13.116135
# min       3.000000     6.000000
# 25%    1545.750000    27.000000
# 50%    3009.500000    35.000000
# 75%    4486.250000    46.000000
# max    5927.000000    91.000000

# %%
df.shape
# Out:
# (5416, 14)

# %%
df.isnull().sum()
# Out:
# id                           0
# name                         0
# date                         0
# manner_of_death              0
# armed                      227
# age                        235
# gender                       2
# race                       521
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                       249
# body_camera                  0
# dtype: int64

# %%
df.columns
# Out:
# Index([u'id', u'name', u'date', u'manner_of_death', u'armed', u'age',
#        u'gender', u'race', u'city', u'state', u'signs_of_mental_illness',
#        u'threat_level', u'flee', u'body_camera'],
#       dtype='object')

# %%
sns.set(style='whitegrid')
sns.barplot(y='race',x='signs_of_mental_illness',hue='gender',data=df)

# %%
sns.set(style='whitegrid')
sns.relplot(y='race',x='manner_of_death',hue='gender',data=df)

# %%
sns.boxplot(x="age",y="armed",data=df)

# %%
g = sns.factorplot("age", "manner_of_death", data=df, kind="bar", palette="muted", legend=False)
                   

plt.show()

# %%
sns.countplot(x='gender',data=df)

# %%
sns.countplot(x='signs_of_mental_illness',data=df)

# %%
sns.countplot(x='threat_level',data=df)

# %%
sns.set(style='whitegrid')
sns.relplot(y='race',x='threat_level',hue='gender',data=df)
